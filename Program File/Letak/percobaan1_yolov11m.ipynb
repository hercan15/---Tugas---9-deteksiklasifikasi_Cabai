# %%
# !pip install ultralytics roboflow

from ultralytics import YOLO
from roboflow import Roboflow
import os
from google.colab import drive
import torch 


drive.mount('/content/drive')


rf = Roboflow(api_key="S7QbNpia7PJtXZ4mS7au")
project = rf.workspace("kematangan-cabai-rawit").project("cabai-rawit-new-tduyf")
version = project.version(2)
dataset = version.download("yolov11")


data_yaml_path = f"{dataset.location}/data.yaml"


output_drive_folder = "/content/drive/MyDrive/YOLOv11_Training_Results-2-2-2" 


try:

  model = YOLO("https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11m.pt")
  print("✅ YOLOv11n model loaded successfully.")
except Exception as e:
  print(f"❌ Failed to load YOLOv11m model: {e}")

  model = YOLO("yolov11m.pt")



device = [0] if torch.cuda.is_available() else 'cpu'

results = model.train(
    data=data_yaml_path,
    epochs=100,
    imgsz=640,
    device=device,  
    project=output_drive_folder, 
    name='yolov11m_training' 
)



print("Training completed!")
print(f"Results saved to: {model.trainer.save_dir}")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 43.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 86.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 84.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# ...
